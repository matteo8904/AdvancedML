# %%
import sys
sys.path.insert(1, 'C:/Users/fabio/Desktop/ML4Fin Unibo')

import numpy  as np
import pandas as pd

import re

import matplotlib.pyplot as plt

from utils import plot_nnpredict_45

# %%
TAG = '1986436'    # same as the seed you set for generation

predictionFile = "prediction_%s.csv" %(TAG)
targetFile = "target_%s.csv" %TAG

# %%
y_hat = pd.read_csv(predictionFile, sep=',')["Price"]
print(y_hat.head(5))
# Out:
# 0    0.275553
# 1    0.457465
# 2    0.255482
# 3    0.232437
# 4    0.466940
# Name: Price, dtype: float64

# %%
y = pd.read_csv(targetFile, sep=',')["Price"]
print(y.head(5))
# Out:
# 0    0.283250
# 1    0.456438
# 2    0.258638
# 3    0.226598
# 4    0.459198
# Name: Price, dtype: float64

# %%
fig, ax = plt.subplots(1,1, figsize=(8,8))  
plot_nnpredict_45(y_hat, y, "challenge set", ax)
